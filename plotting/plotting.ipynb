# %%
import openmc
import matplotlib.pyplot as pyplot
import os
import pickle

import sens_helpers
from sens_helpers.plotting import plot_source, plot_adjoint, plot_all_sens

# %%
# sens_folder = '/home/icmeyer/research/wmp_sensitivity_problems/problems/pu-sol-therm-034-015/sensitivity_run'
sens_folder = '/home/icmeyer/research/wmp_sensitivity_problems/problems/partial_bwr/fresh/sensitivity_run'
is2D = True
os.chdir(sens_folder)
geom = openmc.Geometry.from_xml('geometry.xml')

# %%
plot = openmc.Plot()
# Along z-axis
plot.basis = 'xy'
plot.origin = (0, 0, 1)
plot.width = (10., 10.)
plot.pixels = (400, 400)
plot.to_ipython_image()

# %%
plot = openmc.Plot()
# Along z-axis
plot.basis = 'xy'
plot.origin = (0, 0, 70)
plot.width = (100., 100.)
plot.pixels = (400, 400)
plot.to_ipython_image()

# %%
plot = openmc.Plot()
# Along x-axis
plot.basis = 'yz'
plot.origin = (0, 0, 70)
plot.width = (200., 200.)
plot.pixels = (400, 400)
plot.to_ipython_image()

# %%
plot = openmc.Plot()
# Along y-axis
plot.basis = 'xz'
plot.origin = (21.59, 0, 70)
plot.width = (200., 200.)
plot.pixels = (400, 400)
plot.to_ipython_image()

# %%
from sens_helpers.plotting import plot_source
source_figs = plot_source(is2D)
for fig in source_figs:
    fig.show()
# Out:
# [[5.81484914e-03 1.51074641e-02 6.54578330e-07 1.45978593e-02
#   5.56323282e-03 5.73443604e-03 1.50966859e-02 3.10168015e-07
#   1.55759444e-02 6.02594517e-03]
#  [1.51216308e-02 3.20307045e-02 6.86953777e-04 3.04127290e-02
#   1.44023486e-02 1.47030462e-02 3.21849490e-02 6.84029389e-04
#   3.33906157e-02 1.55698373e-02]
#  [7.03916243e-07 6.54962740e-04 0.00000000e+00 4.89684765e-04
#   3.98268109e-07 1.29920852e-07 6.77654515e-04 0.00000000e+00
#   7.05022288e-04 6.60644330e-08]
#  [1.47424053e-02 3.04728773e-02 5.04681235e-04 1.02096448e-02
#   5.06154308e-03 1.32564002e-02 2.97179417e-02 6.59130536e-04
#   3.22000290e-02 1.52206244e-02]
#  [5.60972914e-03 1.43577526e-02 1.50239859e-07 4.98881036e-03
#   1.95170312e-03 4.86127303e-03 1.33438410e-02 8.40682725e-08
#   1.46867796e-02 5.81478107e-03]
#  [5.73498436e-03 1.47890965e-02 4.67702077e-07 1.32120771e-02
#   4.98187871e-03 2.00555791e-03 5.06903219e-03 1.43736470e-07
#   1.42464648e-02 5.62851640e-03]
#  [1.51448327e-02 3.20768465e-02 6.42836398e-04 2.96942391e-02
#   1.32489193e-02 4.98523003e-03 1.02637736e-02 4.85195288e-04
#   3.05198412e-02 1.46202520e-02]
#  [3.48503537e-07 6.98733949e-04 0.00000000e+00 6.71450798e-04
#   1.03827855e-07 1.24223163e-08 4.81660334e-04 0.00000000e+00
#   6.59348434e-04 5.09550664e-07]
#  [1.55698578e-02 3.32415325e-02 7.08307534e-04 3.20926472e-02
#   1.47860493e-02 1.41425945e-02 3.03814258e-02 6.80988390e-04
#   3.20945352e-02 1.51023836e-02]
#  [6.14624821e-03 1.56092988e-02 2.73231686e-08 1.50628848e-02
#   5.69459528e-03 5.72002252e-03 1.47520783e-02 3.10586502e-07
#   1.50672792e-02 5.80665080e-03]]
# /home/icmeyer/research/wmp_sensitivity_problems/sens_helpers/sens_helpers/plotting.py:65: RuntimeWarning: invalid value encountered in true_divide
#   plot_slice(fig, ax, source/source_sd*100, 'Relative Error', 0, nmesh, is2D, error=True)
# /home/icmeyer/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   after removing the cwd from sys.path.

# %%
adjoint_figs = plot_adjoint(is2D)
for fig in adjoint_figs:
    fig.show()
# Out:
# /home/icmeyer/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
rxns = ['fission', 'absorption', 'elastic']
var_words = ['cross_section', 'multipole', 'curve_fit']
nuclides = sens_helpers.openmc_help.get_nucs_from_mat_xml('materials.xml')
figs = plot_all_sens(nuclides, rxns, var_words)
for fig in figs:
    fig.show()
# Out:
# /home/icmeyer/openmc/openmc/mixin.py:68: IDWarning: Another Material instance already exists with id=3.
#   warn(msg, IDWarning)
# /home/icmeyer/openmc/openmc/mixin.py:68: IDWarning: Another Material instance already exists with id=4.
#   warn(msg, IDWarning)
# /home/icmeyer/openmc/openmc/mixin.py:68: IDWarning: Another Material instance already exists with id=5.
#   warn(msg, IDWarning)
# /home/icmeyer/openmc/openmc/mixin.py:68: IDWarning: Another Material instance already exists with id=6.
#   warn(msg, IDWarning)
# H1 multipole none
# H1 curve_fit none
# H1 cross_section fission
# H1 cross_section absorption
# H1 cross_section elastic
# H2 multipole none
# H2 curve_fit none
# H2 cross_section fission
# H2 cross_section absorption
# H2 cross_section elastic
# O16 multipole none
# O16 curve_fit none
# O16 cross_section fission
# O16 cross_section absorption
# O16 cross_section elastic
# O17 multipole none
# O17 curve_fit none
# O17 cross_section fission
# O17 cross_section absorption
# O17 cross_section elastic
# Fe54 multipole none
# Fe54 curve_fit none
# Fe54 cross_section fission
# Fe54 cross_section absorption
# Fe54 cross_section elastic
# Fe56 multipole none
# Fe56 curve_fit none
# Fe56 cross_section fission
# Fe56 cross_section absorption
# Fe56 cross_section elastic
# Fe57 multipole none
# Fe57 curve_fit none
# Fe57 cross_section fission
# Fe57 cross_section absorption
# Fe57 cross_section elastic
# Fe58 multipole none
# Fe58 curve_fit none
# Fe58 cross_section fission
# Fe58 cross_section absorption
# Fe58 cross_section elastic
# Cr50 multipole none
# Cr50 curve_fit none
# Cr50 cross_section fission
# Cr50 cross_section absorption
# Cr50 cross_section elastic
# Cr52 multipole none
# Cr52 curve_fit none
# Cr52 cross_section fission
# Cr52 cross_section absorption
# Cr52 cross_section elastic
# Cr53 multipole none
# Cr53 curve_fit none
# Cr53 cross_section fission
# Cr53 cross_section absorption
# Cr53 cross_section elastic
# Cr54 multipole none
# Cr54 curve_fit none
# Cr54 cross_section fission
# Cr54 cross_section absorption
# Cr54 cross_section elastic
# Ni58 multipole none
# Ni58 curve_fit none
# Ni58 cross_section fission
# Ni58 cross_section absorption
# Ni58 cross_section elastic
# Ni60 multipole none
# Ni60 curve_fit none
# Ni60 cross_section fission
# Ni60 cross_section absorption
# Ni60 cross_section elastic
# Ni61 multipole none
# Ni61 curve_fit none
# Ni61 cross_section fission
# Ni61 cross_section absorption
# Ni61 cross_section elastic
# Ni62 multipole none
# Ni62 curve_fit none
# Ni62 cross_section fission
# Ni62 cross_section absorption
# Ni62 cross_section elastic
# Ni64 multipole none
# Ni64 curve_fit none
# Ni64 cross_section fission
# Ni64 cross_section absorption
# Ni64 cross_section elastic
# Zr90 multipole none
# Zr90 curve_fit none
# Zr90 cross_section fission
# Zr90 cross_section absorption
# Zr90 cross_section elastic
# Zr91 multipole none
# Zr91 curve_fit none
# Zr91 cross_section fission
# Zr91 cross_section absorption
# Zr91 cross_section elastic
# Zr92 multipole none
# Zr92 curve_fit none
# Zr92 cross_section fission
# Zr92 cross_section absorption
# Zr92 cross_section elastic
# Zr94 multipole none
# Zr94 curve_fit none
# Zr94 cross_section fission
# Zr94 cross_section absorption
# Zr94 cross_section elastic
# Zr96 multipole none
# Zr96 curve_fit none
# Zr96 cross_section fission
# Zr96 cross_section absorption
# Zr96 cross_section elastic
# Gd152 multipole none
# Gd152 curve_fit none
# Gd152 cross_section fission
# Gd152 cross_section absorption
# Gd152 cross_section elastic
# Gd154 multipole none
# Gd154 curve_fit none
# Gd154 cross_section fission
# Gd154 cross_section absorption
# Gd154 cross_section elastic
# Gd155 multipole none
# Gd155 curve_fit none
# Gd155 cross_section fission
# Gd155 cross_section absorption
# Gd155 cross_section elastic
# Gd156 multipole none
# Gd156 curve_fit none
# Gd156 cross_section fission
# Gd156 cross_section absorption
# Gd156 cross_section elastic
# Gd157 multipole none
# Gd157 curve_fit none
# Gd157 cross_section fission
# Gd157 cross_section absorption
# Gd157 cross_section elastic
# Gd158 multipole none
# Gd158 curve_fit none
# Gd158 cross_section fission
# Gd158 cross_section absorption
# Gd158 cross_section elastic
# Gd160 multipole none
# Gd160 curve_fit none
# Gd160 cross_section fission
# Gd160 cross_section absorption
# Gd160 cross_section elastic
# U234 multipole none
# U234 curve_fit none
# U234 cross_section fission
# U234 cross_section absorption
# U234 cross_section elastic
# U235 multipole none
# U235 curve_fit none
# U235 cross_section fission
# U235 cross_section absorption
# U235 cross_section elastic
# U236 multipole none
# U236 curve_fit none
# U236 cross_section fission
# U236 cross_section absorption
# U236 cross_section elastic
# U238 multipole none
# U238 curve_fit none
# U238 cross_section fission
# U238 cross_section absorption
# U238 cross_section elastic
# U238 cross_section fission
# U238 cross_section absorption
# U238 cross_section elastic
# Fe57 cross_section fission
# Fe57 cross_section absorption
# Fe57 cross_section elastic
# Sn112 cross_section fission
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_245903/3902872512.py in <module>
#       2 var_words = ['cross_section', 'multipole', 'curve_fit']
#       3 nuclides = sens_helpers.openmc_help.get_nucs_from_mat_xml('materials.xml')
# ----> 4 figs = plot_all_sens(nuclides, rxns, var_words)
#       5 for fig in figs:
#       6     fig.show()
#
# ~/research/wmp_sensitivity_problems/sens_helpers/sens_helpers/plotting.py in plot_all_sens(nuclides, reactions, var_words)
#     260                 elif var_word == 'cross_section':
#     261                     title = nuc+' '+reaction+' '+var_word
# --> 262                     fig = plot_xs_sens(sens_dict, nuc, var_word, reaction, title)
#     263                 figs.append(fig)
#     264                 fig_names.append('{:s}_{:s}_{:s}'.format(nuc, reaction, var_word))
#
# ~/research/wmp_sensitivity_problems/sens_helpers/sens_helpers/plotting.py in plot_xs_sens(sens_dict, nuc, var, reaction, title)
#     219     sd = sens_dict[nuc][var][reaction]['sd']
#     220
# --> 221     plot_sens_err(ax, e_bins, sens, sd)
#     222
#     223     ax.set_ylabel('Sensitivity')
#
# ~/research/wmp_sensitivity_problems/sens_helpers/sens_helpers/plotting.py in plot_sens_err(ax, e_bins, sens, sens_sd, label)
#     205
#     206 def plot_sens_err(ax, e_bins, sens, sens_sd=None, label=''):
# --> 207     mids = (e_bins[:-1] + e_bins[1:])/2
#     208     step = ax.step(e_bins, hist_y(sens), label=label)
#     209     if sens_sd is not None:
#
# TypeError: unhashable type: 'slice'
