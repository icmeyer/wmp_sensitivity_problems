# %%
import openmc
import matplotlib.pyplot as pyplot
import os
import pickle

import sens_helpers
from sens_helpers.plotting import plot_source, plot_adjoint, plot_all_sens

# %%
# sens_folder = '/home/icmeyer/research/wmp_sensitivity_problems/problems/pu-sol-therm-034-015/sensitivity_run'
sens_folder = '/home/icmeyer/research/wmp_sensitivity_problems/problems/partial_bwr/fresh/sensitivity_run'
is2D = True
os.chdir(sens_folder)
geom = openmc.Geometry.from_xml('geometry.xml')

# %%
plot = openmc.Plot()
# Along z-axis
plot.basis = 'xy'
plot.origin = (0, 0, 1)
plot.width = (10., 10.)
plot.pixels = (400, 400)
plot.to_ipython_image()

# %%
plot = openmc.Plot()
# Along z-axis
plot.basis = 'xy'
plot.origin = (0, 0, 70)
plot.width = (100., 100.)
plot.pixels = (400, 400)
plot.to_ipython_image()

# %%
plot = openmc.Plot()
# Along x-axis
plot.basis = 'yz'
plot.origin = (0, 0, 70)
plot.width = (200., 200.)
plot.pixels = (400, 400)
plot.to_ipython_image()

# %%
plot = openmc.Plot()
# Along y-axis
plot.basis = 'xz'
plot.origin = (21.59, 0, 70)
plot.width = (200., 200.)
plot.pixels = (400, 400)
plot.to_ipython_image()

# %%
from sens_helpers.plotting import plot_source
source_figs = plot_source(is2D)
for fig in source_figs:
    fig.show()
# Out:
# [[0.00000000e+00 0.00000000e+00 4.66555799e-05 2.42727843e-07
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 3.24706709e-05
#   5.66416579e-06 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   5.86707433e-06 3.34338963e-05 3.92566495e-09 0.00000000e+00
#   0.00000000e+00 1.18437236e-07 3.88312320e-05 1.13763373e-07
#   0.00000000e+00]
#  [3.35596218e-09 4.22465567e-03 8.07692827e-03 5.90801026e-03
#   1.74847408e-04 0.00000000e+00 2.41622419e-03 7.45876435e-03
#   6.84150580e-03 1.02638962e-03 0.00000000e+00 1.07879919e-03
#   7.01706558e-03 7.76530879e-03 2.50766814e-03 0.00000000e+00
#   1.80369625e-04 6.15062485e-03 8.28714015e-03 4.39854587e-03
#   0.00000000e+00]
#  [4.19024040e-05 8.04867318e-03 7.81828136e-03 7.96753299e-03
#   1.95810729e-03 2.74233256e-07 5.81309862e-03 7.42920704e-03
#   7.64222516e-03 3.84967180e-03 0.00000000e+00 3.89260216e-03
#   7.76508295e-03 7.92003849e-03 6.13312759e-03 0.00000000e+00
#   2.02882970e-03 8.29283615e-03 8.12031759e-03 8.26099953e-03
#   4.19694236e-05]
#  [2.76896795e-08 5.94837077e-03 8.00703077e-03 7.27906875e-03
#   5.77005256e-04 0.00000000e+00 3.64210135e-03 7.60719630e-03
#   7.44858206e-03 1.92186663e-03 0.00000000e+00 1.91873250e-03
#   7.82632679e-03 7.94895403e-03 3.90221597e-03 0.00000000e+00
#   5.91226127e-04 7.56636548e-03 8.33948093e-03 6.15990314e-03
#   3.97593751e-07]
#  [0.00000000e+00 1.76727654e-04 1.94926079e-03 5.48597341e-04
#   0.00000000e+00 0.00000000e+00 9.92199078e-07 1.47503393e-03
#   1.00330038e-03 0.00000000e+00 0.00000000e+00 1.57331286e-07
#   1.07718910e-03 1.58359683e-03 9.43328324e-07 0.00000000e+00
#   0.00000000e+00 5.82856802e-04 2.06064054e-03 1.83846581e-04
#   0.00000000e+00]
#  [0.00000000e+00 0.00000000e+00

#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   1.95066958e-08 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00]
#  [0.00000000e+00 1.78415750e-04 2.04142497e-03 5.56191658e-04
#   0.00000000e+00 0.00000000e+00 1.72061997e-06 1.60622062e-03
#   1.05760847e-03 0.00000000e+00 0.00000000e+00 3.40620890e-07
#   9.76766802e-04 1.50173061e-03 1.50918644e-06 0.00000000e+00
#   0.00000000e+00 5.85320167e-04 1.94732530e-03 1.75825202e-04
#   0.00000000e+00]
#  [2.87142897e-07 6.16917799e-03 8.16502170e-03 7.63073139e-03
#   6.02381489e-04 0.00000000e+00 3.96610477e-03 7.99963037e-03
#   7.73067360e-03 1.96563482e-03 0.00000000e+00 1.88180678e-03
#   7.25441536e-03 7.47088757e-03 3.70421855e-03 0.00000000e+00
#   5.64595546e-04 7.34770358e-03 8.07755825e-03 5.94681785e-03
#   9.94861603e-09]
#  [4.43114052e-05 8.26923145e-03 8.10986967e-03 8.31276562e-03
#   2.03760150e-03 0.00000000e+00 6.03783558e-03 7.89874584e-03
#   7.86129187e-03 3.95991639e-03 0.00000000e+00 3.89360698e-03
#   7.57580996e-03 7.54247320e-03 5.76421115e-03 0.00000000e+00
#   1.98623458e-03 7.91577369e-03 7.74761894e-03 8.03910940e-03
#   3.68855273e-05]
#  [4.82394536e-07 4.41808689e-03 8.31189022e-03 6.20401818e-03
#   1.85370386e-04 0.00000000e+00 2.52497669e-03 7.67569198e-03
#   6.93630072e-03 1.07043762e-03 0.00000000e+00 1.07169560e-03
#   6.94327777e-03 7.56584381e-03 2.44956001e-03 0.00000000e+00
#   1.74007673e-04 5.90287522e-03 8.05234346e-03 4.20650884e-03
#   1.43058122e-07]
#  [0.00000000e+00 0.00000000e+00 3.55053816e-05 9.85487872e-07
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 3.27930239e-05
#   6.55979998e-06 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   4.78815620e-06 3.54321693e-05 2.91328367e-08 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 4.11507519e-05 2.35290216e-08
#   0.00000000e+00]]
# /home/icmeyer/research/wmp_sensitivity_problems/sens_helpers/sens_helpers/plotting.py:65: RuntimeWarning: invalid value encountered in true_divide
#   plot_slice(fig, ax, source_sd/source*100, 'Relative Error', 0, nmesh, is2D, error=True)
# /home/icmeyer/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   after removing the cwd from sys.path.

# %%
adjoint_figs = plot_adjoint(is2D)
for fig in adjoint_figs:
    fig.show()
# Out:
# /home/icmeyer/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
rxns = ['fission', 'absorption', 'elastic']
var_words = ['cross_section', 'multipole', 'curve_fit']
nuclides = sens_helpers.openmc_help.get_nucs_from_mat_xml('materials.xml')
figs = plot_all_sens(nuclides, rxns, var_words)
for fig in figs:
    fig.show()
# Out:
# /home/icmeyer/openmc/openmc/mixin.py:68: IDWarning: Another Material instance already exists with id=3.
#   warn(msg, IDWarning)
# /home/icmeyer/openmc/openmc/mixin.py:68: IDWarning: Another Material instance already exists with id=4.
#   warn(msg, IDWarning)
# /home/icmeyer/openmc/openmc/mixin.py:68: IDWarning: Another Material instance already exists with id=5.
#   warn(msg, IDWarning)
# /home/icmeyer/openmc/openmc/mixin.py:68: IDWarning: Another Material instance already exists with id=6.
#   warn(msg, IDWarning)
# H1 multipole none
# H1 curve_fit none
# H1 cross_section fission
# H1 cross_section absorption
# H1 cross_section elastic
# H2 multipole none
# H2 curve_fit none
# H2 cross_section fission
# H2 cross_section absorption
# H2 cross_section elastic
# O16 multipole none
# O16 curve_fit none
# O16 cross_section fission
# O16 cross_section absorption
# O16 cross_section elastic
# O17 multipole none
# O17 curve_fit none
# O17 cross_section fission
# O17 cross_section absorption
# O17 cross_section elastic
# Fe54 multipole none
# Fe54 curve_fit none
# Fe54 cross_section fission
# Fe54 cross_section absorption
# Fe54 cross_section elastic
# Fe56 multipole none
# Fe56 curve_fit none
# Fe56 cross_section fission
# Fe56 cross_section absorption
# Fe56 cross_section elastic
# Fe57 multipole none
# Fe57 curve_fit none
# Fe57 cross_section fission
# Fe57 cross_section absorption
# Fe57 cross_section elastic
# Fe58 multipole none
# Fe58 curve_fit none
# Fe58 cross_section fission
# Fe58 cross_section absorption
# Fe58 cross_section elastic
# Cr50 multipole none
# Cr50 curve_fit none
# Cr50 cross_section fission
# Cr50 cross_section absorption
# Cr50 cross_section elastic
# Cr52 multipole none
# Cr52 curve_fit none
# Cr52 cross_section fission
# Cr52 cross_section absorption
# Cr52 cross_section elastic
# Cr53 multipole none
# Cr53 curve_fit none
# Cr53 cross_section fission
# Cr53 cross_section absorption
# Cr53 cross_section elastic
# Cr54 multipole none
# Cr54 curve_fit none
# Cr54 cross_section fission
# Cr54 cross_section absorption
# Cr54 cross_section elastic
# Ni58 multipole none
# Ni58 curve_fit none
# Ni58 cross_section fission
# Ni58 cross_section absorption
# Ni58 cross_section elastic
# Ni60 multipole none
# Ni60 curve_fit none
# Ni60 cross_section fission
# Ni60 cross_section absorption
# Ni60 cross_section elastic
# Ni61 multipole none
# Ni61 curve_fit none
# Ni61 cross_section fission
# Ni61 cross_section absorption
# Ni61 cross_section elastic
# Ni62 multipole none
# Ni62 curve_fit none
# Ni62 cross_section fission
# Ni62 cross_section absorption
# Ni62 cross_section elastic
# Ni64 multipole none
# Ni64 curve_fit none
# Ni64 cross_section fission
# Ni64 cross_section absorption
# Ni64 cross_section elastic
# Zr90 multipole none
# Zr90 curve_fit none
# Zr90 cross_section fission
# Zr90 cross_section absorption
# Zr90 cross_section elastic
# Zr91 multipole none
# Zr91 curve_fit none
# Zr91 cross_section fission
# Zr91 cross_section absorption
# Zr91 cross_section elastic
# Zr92 multipole none
# Zr92 curve_fit none
# Zr92 cross_section fission
# Zr92 cross_section absorption
# Zr92 cross_section elastic
# Zr94 multipole none
# Zr94 curve_fit none
# Zr94 cross_section fission
# Zr94 cross_section absorption
# Zr94 cross_section elastic
# Zr96 multipole none
# Zr96 curve_fit none
# Zr96 cross_section fission
# Zr96 cross_section absorption
# Zr96 cross_section elastic
# Gd152 multipole none
# Gd152 curve_fit none
# Gd152 cross_section fission
# Gd152 cross_section absorption
# Gd152 cross_section elastic
# Gd154 multipole none
# Gd154 curve_fit none
# Gd154 cross_section fission
# Gd154 cross_section absorption
# Gd154 cross_section elastic
# Gd155 multipole none
# Gd155 curve_fit none
# Gd155 cross_section fission
# Gd155 cross_section absorption
# Gd155 cross_section elastic
# Gd156 multipole none
# Gd156 curve_fit none
# Gd156 cross_section fission
# Gd156 cross_section absorption
# Gd156 cross_section elastic
# Gd157 multipole none
# Gd157 curve_fit none
# Gd157 cross_section fission
# Gd157 cross_section absorption
# Gd157 cross_section elastic
# Gd158 multipole none
# Gd158 curve_fit none
# Gd158 cross_section fission
# Gd158 cross_section absorption
# Gd158 cross_section elastic
# Gd160 multipole none
# Gd160 curve_fit none
# Gd160 cross_section fission
# Gd160 cross_section absorption
# Gd160 cross_section elastic
# U234 multipole none
# U234 curve_fit none
# U234 cross_section fission
# U234 cross_section absorption
# U234 cross_section elastic
# U235 multipole none
# U235 curve_fit none
# U235 cross_section fission
# U235 cross_section absorption
# U235 cross_section elastic
# U236 multipole none
# U236 curve_fit none
# U236 cross_section fission
# U236 cross_section absorption
# U236 cross_section elastic
# U238 multipole none
# U238 curve_fit none
# U238 cross_section fission
# U238 cross_section absorption
# U238 cross_section elastic
# Ni58 cross_section fission
# Ni58 cross_section absorption
# Ni58 cross_section elastic
# Zr94 cross_section fission
# Zr94 cross_section absorption
# Zr94 cross_section elastic
# Fe56 cross_section fission
# Fe56 cross_section absorption
# Fe56 cross_section elastic
# Sn122 cross_section fission
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_118583/3902872512.py in <module>
#       2 var_words = ['cross_section', 'multipole', 'curve_fit']
#       3 nuclides = sens_helpers.openmc_help.get_nucs_from_mat_xml('materials.xml')
# ----> 4 figs = plot_all_sens(nuclides, rxns, var_words)
#       5 for fig in figs:
#       6     fig.show()
#
# ~/research/wmp_sensitivity_problems/sens_helpers/sens_helpers/plotting.py in plot_all_sens(nuclides, reactions, var_words)
#     259                 elif var_word == 'cross_section':
#     260                     title = nuc+' '+reaction+' '+var_word
# --> 261                     fig = plot_xs_sens(sens_dict, nuc, var_word, reaction, title)
#     262                 figs.append(fig)
#     263                 fig_names.append('{:s}_{:s}_{:s}'.format(nuc, reaction, var_word))
#
# ~/research/wmp_sensitivity_problems/sens_helpers/sens_helpers/plotting.py in plot_xs_sens(sens_dict, nuc, var, reaction, title)
#     218     sd = sens_dict[nuc][var][reaction]['sd']
#     219
# --> 220     plot_sens_err(ax, e_bins, sens, sd)
#     221
#     222     ax.set_ylabel('Sensitivity')
#
# ~/research/wmp_sensitivity_problems/sens_helpers/sens_helpers/plotting.py in plot_sens_err(ax, e_bins, sens, sens_sd, label)
#     204
#     205 def plot_sens_err(ax, e_bins, sens, sens_sd=None, label=''):
# --> 206     mids = (e_bins[:-1] + e_bins[1:])/2
#     207     step = ax.step(e_bins, hist_y(sens), label=label)
#     208     if sens_sd is not None:
#
# TypeError: unhashable type: 'slice'
